# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosOrte/Descriptive-and-Predictive-Analytics-Code/blob/main/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Práctica 3. Creación de un arreglo y operaciones básicas**
#
# Maestría en Inteligencia artificial y analítica de datos
#
# Programación para analítica descriptiva y predictiva
#
# Matrícula: 266231

# %% [markdown]
# **Creamos un arreglo de 20 elementos aleatorios entre 1 y 100**

# %%
import numpy as np

arreglo = np.random.randint(1, 100, 20)

print("Arreglo original:")
print(arreglo)
# Out:
# Arreglo original:
# [82, 7, 22, 46, 83, 79, 64, 71, 54, 91, 19, 26, 4, 62, 33, 98, 10, 43, 87, 76]

# %% [markdown]
# **Buscamos el valor máximo...**

# %%
maximo = max(arreglo)
print("\nValor máximo:", maximo)
# Out:
# Valor máximo: 98

# %% [markdown]
# **Luego el valor mínimo...**

# %%
minimo = min(arreglo)
print("Valor mínimo:", minimo)
# Out:
# Valor mínimo: 4

# %% [markdown]
# **El valor de la media se define de la siguiente manera...**

# %%
media = sum(arreglo) / len(arreglo)
print("Media del arreglo:", media)
# Out:
# Media del arreglo: 52.85

# %% [markdown]
# **Finalmente sumamos 10 a cada elemento del arreglo...**

# %%
arreglo_mas_10 = [x + 10 for x in arreglo]
print("\nArreglo con 10 sumado a cada elemento:")
print(arreglo_mas_10)
# Out:
# Arreglo con 10 sumado a cada elemento:
# [92, 17, 32, 56, 93, 89, 74, 81, 64, 101, 29, 36, 14, 72, 43, 108, 20, 53, 97, 86]
