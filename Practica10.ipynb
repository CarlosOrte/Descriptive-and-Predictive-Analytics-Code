# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosOrte/Descriptive-and-Predictive-Analytics-Code/blob/main/Practica10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Práctica 10: Análisis de Ventas con GridSpec**
#
# Maestría en Inteligencia artificial y analítica de datos
#
# Programación para analítica descriptiva y predictiva
#
# Matrícula: 266231

# %% [markdown]
# # Importar librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1) DataFrame de ventas

# %%
np.random.seed(42)

meses = ["Ene","Feb","Mar","Abr","May","Jun","Jul","Ago","Sep","Oct","Nov","Dic"]
df = pd.DataFrame({
    "Mes": meses,
    "Ventas": np.random.randint(2000, 5001, size=12),
    "Gastos": np.random.randint(1000, 4001, size=12)
})

# %% [markdown]
# # 2) GridSpec para subplots de diferentes tamaños

# %%
fig = plt.figure(figsize=(12, 8))
gs = fig.add_gridspec(2, 3)
# No corregido

# %% [markdown]
# # Primer gráfico: barra, ocupando dos columnas (arriba izquierda)

# %%
ax1 = fig.add_subplot(gs[0, 0:2])
ax1.bar(df["Mes"], df["Ventas"])
ax1.set_title("Ventas por mes (Barras)")
ax1.set_xlabel("Mes")
ax1.set_ylabel("Ventas")
# No corregido
# Out:
# Text(0, 0.5, 'Ventas')

# %% [markdown]
# # Segundo gráfico: línea, una columna (arriba derecha)

# %%
ax2 = fig.add_subplot(gs[0, 2])
ax2.plot(df["Mes"], df["Gastos"], marker="o")
ax2.set_title("Gastos por mes (Línea)")
ax2.set_xlabel("Mes")
ax2.set_ylabel("Gastos")
# No corregido
# Out:
# Text(0, 0.5, 'Gastos')

# %% [markdown]
# # Tercer gráfico: dispersión, dos filas (columna derecha completa en filas restantes)

# %%
ax3 = fig.add_subplot(gs[1, :])
ax3.scatter(df["Ventas"], df["Gastos"])
ax3.set_title("Ventas vs Gastos (Dispersión)")
ax3.set_xlabel("Ventas")
ax3.set_ylabel("Gastos")
# No corregido
# Out:
# Text(0, 0.5, 'Gastos')

# %% [markdown]
# # 3) Ajustar espacios

# %%
plt.tight_layout()
plt.show()
# No corregido

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
